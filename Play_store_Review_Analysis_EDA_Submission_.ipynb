# %% [markdown]
# <a href="https://colab.research.google.com/github/albin2122/Play-Store-App-Review-Analysis/blob/main/Play_store_Review_Analysis_EDA_Submission_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -  PLAYSTORE REVIEW ANALYSIS

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Google Play, also known as the Google Play Store and formerly the Android Market, is a digital distribution service operated and developed by Google. It serves as the official app store for certified devices running on the Android operating system and its derivatives, as well as ChromeOS, allowing users to browse and download applications developed with the Android software development kit (SDK) and published through Google. Google Play has also served as a digital media store, offering games, music, books, movies, and television programs. \
#
# ![unnamed.png](data:image/png;base64,...)
# Since most Play Store applications are free, the income model is very obscure and inaccessible regarding how the in-application buys, in-application adverts and memberships add to the achievement of an application. In this way, an application's prosperity is normally dictated by the quantity of installation of the application and the client appraisals that it has gotten over its lifetime instead of the income is created. In todays scenario , the amount of information that one holds is enormous and the mobile apps plays an important role in any individuals life. As the challenges is higher , it is important for a developer to know the current trends in the appstore. In this project we tried to understand the popularity of an application using different attributes like categories , installs, price, size etc . \
# we have 2 datasets playstore data and user review data. playstore data contains 10841 rows and 13 columns and for user review data 64295 rows and 5 columns of data
# In the inital phase we tried to get a overall look of the data , how it lies, what kind of data it represents. Then we proceed cleaning inorder to avoid the null values and duplicate values. AS we have 2 set of data , we did one by one for more clarification. About 13.5% of Rating column is Null/Missing. Also columns Type,Content Rating are missing 1 value each and columns Current Ver , Android Ver were missing 8 and 3 values respectively.Rating of any app is in between 1 and 5 .The column Rating contains around 13.5% of data and it is not practical to remove it .Therefore the NaN values can be replaced by median or mean of the rest of rating column. About 42 % of user reviews data  were missing. We cant do anything regarding that since the data talks about sentiment and all, and we removed it. \
# With the cleaned data, we have performed Exploratory Data Analysis to understand our dataset like number of installations for each category We explore the correlation between the size of the app and the version of Android on the number of installs and so on. \
# It was found that categories such as Family, Games and tools holds the most number of Apps in the Playstore.
# The Price is slightly negatively correlated with the Rating, Reviews, and Installs. This means that as the prices of the app increases, the average rating, total number of reviews and Installs fall slightly
# Each category is showing a huge differnece in installs between paid and free apps.we found out that  people are spending more money on the game and family.  communication and games are the most installed free apps categories in the playstore and even people spending large amount of money over the apps that comes under the category games. The count of installs in communication category between free and paid is considerably huge. \
#
# Most of the rating is in between 4.0 to 4.5,and
# games have highest sentimentality,comics have the lowest sentimentality acccording to category.
# Mostly people download/install apps that can use by everyone. second most downlaoded apps that can be used by atleast become teens. 18+ apps are downloaded by a minute amount of people compared to others.
# The maximum number of sentiment subjectivity lies between 0.4 to 0.7, and sentiment subjectivity is not always proportional to sentiment polarity.From this we can conclude that maximum number of users give reviews to the applications, according to their experience
# Positive reviews are 64.30% ,Negative reviews are 22.80% and Neutral reviews are 12.90% hence a large number of people using playstore were satisfied
# most of the categories have a price range in between 0 and 25. categories like events , finance, lifestyle have a price varied vastly from other categories. \
# From the results and process we have implemented, we can conclude that we have achieved this  project objective which is analyzing the Google Play Store apps and determine trends of the Google Play Store.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/albin2122/Play-Store-App-Review-Analysis

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# Google play store app review analysis is Prominently needed for the companies that build app and games and provide services through those platforms.
# Google Play, also branded as the Google Play Store and formerly Android Market, is a digital distribution service operated and developed by Google.It is an online store where people go to find their favorite apps, games, movies, TV shows, books, and more.It provides 2 million apps & games to billions of people around the world, generating over $120 billion in earnings for developers to date.
# For new budding companies or companies that want to step into the App development, it is important to know what sort of apps/games that they want to make inorder to get high returns. \
# Problem statements: \
#
#
# *   Major categories of apps in the playstore
# *   categories having higher number of install count
# *  Number of paid apps and free apps
# * How price determines the installs count?
# * How rating affects the apps?
# * Relation between sentiment subjectivity and polarity ?
# * Analysis on sentiment
# * Apps with highest positive ratings
# * Apps recieved most negative reviews
# * Reviews across categories
# * App pricing across categories

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Playstore contains large number of data. And it is the major source of data in the current scenario.A few thousands of new applications are regularly uploaded on Google play store. A huge number of developers working freely on developing the apps and making them successful. With the enormous challenge from everywhere throughout the globe, it is important for a developer to know whether he/she is continuing the correct way or not.Our business objective is to have a clear idea about  how playstore works and trends of apps according to the various attributes .We need to find the major categories.Relation between paid and free apps and how it affects the installs counts. After carefull analysing we need to form an objective which could benefit the business . \
# * We need to find the category which could flourish the investment.
#
# The outcome of this project should be a plan  that helps the developer / investor to invest their money and time in a efficient manner.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns  
import missingno as msno
from datetime import datetime

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
playstore_df=pd.read_csv('/content/drive/MyDrive/AlmaBetter/Modules/Topics/Project/Play Store Data.csv')
review_df=pd.read_csv('/content/drive/MyDrive/AlmaBetter/Modules/Topics/Project/User Reviews.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look of playstore data
first_look=playstore_df.head().append(playstore_df.tail())
first_look
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# ...

# %%
# Dataset First Look of review data
first_look_review=review_df.head().append(review_df.tail())
first_look_review
# Out:
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# 64290                                                NaN       NaN
# 64291                                                NaN       NaN
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# playstore_df Dataset Rows & Columns count
row_count=playstore_df.shape[0]
print(f'no of rows is {row_count} ')
# Out:
# no of rows is 10841

# %%
column_count=playstore_df.shape[1]
print(f'no of columns is {column_count}')
# Out:
# no of columns is 13

# %%
# review_df  Dataset Rows & Columns count
print(f'no of rows is {review_df.shape[0]} and no of columns is {review_df.shape[1]}')
# Out:
# no of rows is 64295 and no of columns is 5

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info

# %%
playstore_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %% [markdown]
# #### Duplicate Values

# %% [markdown]
# If there is any duplicates value in playstore database, we can identify it through 'App' column since it is the only column that is unique.

# %%
# Dataset Duplicate Value Count
playstore_df['App'].value_counts()
# Out:
# ROBLOX                                                9
# CBS Sports App - Scores, News, Stats & Watch Live     8
# ESPN                                                  7
# Duolingo: Learn Languages Free                        7
# Candy Crush Saga                                      7
#                                                      ..
# Meet U - Get Friends for Snapchat, Kik & Instagram    1
# U-Report                                              1
# U of I Community Credit Union                         1
# Waiting For U Launcher Theme                          1
# iHoroscope - 2018 Daily Horoscope & Astrology         1
# Name: App, Length: 9660, dtype: int64

# %%
#checking whether it is duplicate or not by taking ESPN as example
playstore_df[playstore_df['App']=='ESPN']
# Out:
#        App Category  Rating Reviews                Size     Installs  Type  \
# 2959  ESPN   SPORTS     4.2  521138  Varies with device  10,000,000+  Free
# 3010  ESPN   SPORTS     4.2  521138  Varies with device  10,000,000+  Free
# 3018  ESPN   SPORTS     4.2  521138  Varies with device  10,000,000+  Free
# 3048  ESPN   SPORTS     4.2  521140  Varies with device  10,000,000+  Free
# 3060  ESPN   SPORTS     4.2  521140  Varies with device  10,000,000+  Free
# 3072  ESPN   SPORTS     4.2  521140  Varies with device  10,000,000+  Free
# 4069  ESPN   SPORTS     4.2  521081  Varies with device  10,000,000+  Free
#
#      Price Content Rating  Genres   Last Updated         Current Ver  \
# 2959     0   Everyone 10+  Sports  July 19, 2018  Varies with device
# 3010     0   Everyone 10+  Sports  July 19, 2018  Varies with device
# 3018     0   Everyone 10+  Sports  July 19, 2018  Varies with device
# 3048     0   Everyone 10+  Sports  July 19, 2018  Varies with device
# ...

# %% [markdown]
# Datas are all same . Duplicate values detected

# %%
# therefore duplicate values in the playstore database is 
playstore_df[playstore_df.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
# ...

# %% [markdown]
# #### Missing Values/Null Values of  **Play store Database**

# %%
# Missing Values/Null Values Count
missing_count=playstore_df.isnull().sum()
percentage=(playstore_df.isnull().sum()/playstore_df.shape[0])*100

# %%
print(missing_count)
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
print(percentage)
# Out:
# App                0.000000
# Category           0.000000
# Rating            13.596532
# Reviews            0.000000
# Size               0.000000
# Installs           0.000000
# Type               0.009224
# Price              0.000000
# Content Rating     0.009224
# Genres             0.000000
# Last Updated       0.000000
# Current Ver        0.073794
# Android Ver        0.027673
# dtype: float64

# %%
# Visualizing the missing values
msno.bar(playstore_df)

# %% [markdown]
# Here you can immediately see that the Rating  features is  missing some  values. About 13.5% of Rating column is Null/Missing. closer look also reveals that the columns Type,Content Rating are missing 1 value each and columns Current Ver , Android Ver were missing 8 and 3 values respectively.
#
# we need to treat this features seprately to come up with a way to replace or remove from the DataFrame

# %%
msno.heatmap(playstore_df)

# %% [markdown]
# First of all,  there are only five features present in the heatmap. This is because there are only five features that are missing values. All the other features are discarded from the plot.
# The value that corresponds Content Rating  and Android ver. The value is 0.6 .This means that there is a  correspondence between missing values in Content Rating and missing values in Android ver.A value of 0 indicates that there is no obvious correspondence between missing values.since  other features having a value of 0, there is no obvious correspondence between this missing values

# %% [markdown]
# #### Missing Values/Null Values of  **User Review Database**

# %%
missing_count_review=review_df.isnull().sum()
percentage_rev=(review_df.isnull().sum()/review_df.shape[0])*100

# %%
print(missing_count_review)
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
print(percentage_rev)
# Out:
# App                        0.000000
# Translated_Review         41.788631
# Sentiment                 41.780854
# Sentiment_Polarity        41.780854
# Sentiment_Subjectivity    41.780854
# dtype: float64

# %%
review_df.columns
# Out:
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
msno.bar(review_df)

# %% [markdown]
# About 42 % of 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
# 'Sentiment_Subjectivity' were missing.

# %%
msno.matrix(review_df)

# %% [markdown]
# The missing values are located all over the place.

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# **Playstore database:**
# contain columns 'App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type','Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver' 'Android Ver' and having 10841 rows.
#
# ---
#
#
# **Review database:**
#
# Contain columns 'App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
# 'Sentiment_Subjectivity and 64295 rows. Around 42% of 'Translated_Review', 'Sentiment', 'Sentiment_Polarity','Sentiment_Subjectivity' are null values.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %% [markdown]
# Playstore_Database

# %%
# Dataset Columns
playstore_df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
# Dataset Describe
playstore_df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %% [markdown]
# Review Database

# %%
review_df.columns
# Out:
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
review_df.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37432.000000            37432.000000
# mean             0.182146                0.492704
# std              0.351301                0.259949
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000

# %% [markdown]
# ### Variables Description

# %% [markdown]
# ### Playstore Database
# App - It tells us about the name of the application with a short description.\
# Category - It gives the category to the app.\
# Rating - It contains the average rating the respective app received from its users.\
# Reviews - It tells us about the total number of users who have given a review for the application.\
# Size - It tells us about the size being occupied the application on the mobile phone.\
# Installs - It tells us about the total number of installs/downloads for an application.\
# Type - It states whether an app is free to use or paid.\
# Price - It gives the price payable to install the app. For free type apps, the price is zero.\
# Content Rating - It states whether or not an app is suitable for all age groups or not.\
# Genres - It tells us about the various other categories to which an application can belong.\
# Last Updated - It tells us about the when the application was updated.\
# Current Ver - It tells us about the current version of the application\
#
# ### Review Database
# App: Contains the name of the app with a short description. \
# Translated_Review: It contains the English translation of the review dropped by the user of the app.\
# Sentiment: It gives the attitude/emotion of the writer. It can be ‘Positive’, ‘Negative’, or ‘Neutral’.\
# Sentiment_Polarity: It gives the polarity of the review. Its range is [-1,1], where 1 means ‘Positive statement’ and -1 means a ‘Negative statement’.\
# Sentiment_Subjectivity: This value gives how close a reviewers opinion is to the opinion of the general public. Its range is [0,1]. Higher the subjectivity, closer is the reviewers opinion to the opinion of the general public, and lower subjectivity indicates the review is more of a factual information.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for uni in playstore_df.columns:
  unique_values=playstore_df[uni].unique()
  print(f'unique values in {uni} column are {unique_values}')
# Out:
# unique values in App column are ['Photo Editor & Candy Camera & Grid & ScrapBook' 'Coloring book moana'
#  'U Launcher Lite – FREE Live Cool Themes, Hide Apps' ...
#  'Parkinson Exercices FR' 'The SCP Foundation DB fr nn5n'
#  'iHoroscope - 2018 Daily Horoscope & Astrology']
# unique values in Category column are ['ART_AND_DESIGN' 'AUTO_AND_VEHICLES' 'BEAUTY' 'BOOKS_AND_REFERENCE'
#  'BUSINESS' 'COMICS' 'COMMUNICATION' 'DATING' 'EDUCATION' 'ENTERTAINMENT'
#  'EVENTS' 'FINANCE' 'FOOD_AND_DRINK' 'HEALTH_AND_FITNESS' 'HOUSE_AND_HOME'
#  'LIBRARIES_AND_DEMO' 'LIFESTYLE' 'GAME' 'FAMILY' 'MEDICAL' 'SOCIAL'
#  'SHOPPING' 'PHOTOGRAPHY' 'SPORTS' 'TRAVEL_AND_LOCAL' 'TOOLS'
#  'PERSONALIZATION' 'PRODUCTIVITY' 'PARENTING' 'WEATHER' 'VIDEO_PLAYERS'
#  'NEWS_AND_MAGAZINES' 'MAPS_AND_NAVIGATION' '1.9']
# unique values in Rating column are [ 4.1  3.9  4.7  4.5  4.3  4.4  3.8  4.2  4.6  3.2  4.   nan  4.8  4.9
#   3.6  3.7  3.3  3.4  3.5  3.1  5.   2.6  3.   1.9  2.5  2.8  2.7  1.
# ...

# %%
for uni in review_df.columns:
  unique_values=review_df[uni].unique()
  print(f'unique values in {uni} column are {unique_values}')
# Out:
# unique values in App column are ['10 Best Foods for You' '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室' '11st' ...
#  'Hotwire Hotel & Car Rental App' 'Housing-Real Estate & Property'
#  'Houzz Interior Design Ideas']
# unique values in Translated_Review column are ['I like eat delicious food. That\'s I\'m cooking food myself, case "10 Best Foods" helps lot, also "Best Before (Shelf Life)"'
#  'This help eating healthy exercise regular basis' nan ...
#  'Dumb app, I wanted post property rent give option. Website work. Waste time space phone.'
#  'I property business got link SMS happy performance still guys need raise bar guys Cheers'
#  'Useless app, I searched flats kondapur, Hyderabad . None number reachable I know flats unavailable would keep posts active']
# unique values in Sentiment column are ['Positive' nan 'Neutral' 'Negative']
# unique values in Sentiment_Polarity column are [ 1.          0.25               nan ... -0.52857143 -0.37777778
#   0.17333333]
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %% [markdown]
# ### Cleaning Playstore Database
#
# Cleaning the data includes removing the special characters like $,.+ and letters Mk from the installs column, Removing the Nan value and Duplicate present in the data set.converting each column into numerical datatype.
# ## 1.Handling Null/Missing values

# %% [markdown]
# 1. column Type --only one missing value in this column

# %%
playstore_df['Type'].value_counts()
# Out:
# Free    10039
# Paid      800
# 0           1
# Name: Type, dtype: int64

# %% [markdown]
# Column Type has four values ----Free, paid, 0 and NaN.The row containing NaN value can be replaced by either Free or Paid as per the price. That is if the price is zero then it is free, if it is not then paid

# %%
playstore_df[playstore_df['Type'].isnull()]
# Out:
#                             App Category  Rating Reviews                Size  \
# 9148  Command & Conquer: Rivals   FAMILY     NaN       0  Varies with device
#
#      Installs Type Price Content Rating    Genres   Last Updated  \
# 9148        0  NaN     0   Everyone 10+  Strategy  June 28, 2018
#
#              Current Ver         Android Ver
# 9148  Varies with device  Varies with device

# %% [markdown]
# price is zero , therefore NaN value can be replaced by Free

# %%
playstore_df.loc[9148,'Type']='Free'

# %%
playstore_df.loc[9148]
# Out:
# App               Command & Conquer: Rivals
# Category                             FAMILY
# Rating                                  NaN
# Reviews                                   0
# Size                     Varies with device
# Installs                                  0
# Type                                   Free
# Price                                     0
# Content Rating                 Everyone 10+
# Genres                             Strategy
# Last Updated                  June 28, 2018
# Current Ver              Varies with device
# Android Ver              Varies with device
# Name: 9148, dtype: object

# %% [markdown]
# one row contain value 0 to the column 'Type'

# %%
playstore_df[playstore_df['Type']=='0']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %% [markdown]
# There is a mismatch of data from the column Reviews to the last column.value of column 'Size' is taken by Column 'Reviews' and so on.it is better to drop the row

# %%
playstore_df.drop([10472],axis=0,inplace=True)

# %% [markdown]
# 2.column -Android version -2 missing values

# %%
playstore_df[playstore_df["Android Ver"].isnull()]
# Out:
#                          App         Category  Rating Reviews  Size Installs  \
# 4453  [substratum] Vacuum: P  PERSONALIZATION     4.4     230   11M   1,000+
# 4490    Pi Dark [substratum]  PERSONALIZATION     4.5     189  2.1M  10,000+
#
#       Type  Price Content Rating           Genres    Last Updated Current Ver  \
# 4453  Paid  $1.49       Everyone  Personalization   July 20, 2018         4.4
# 4490  Free      0       Everyone  Personalization  March 27, 2018         1.1
#
#      Android Ver
# 4453         NaN
# 4490         NaN

# %%
playstore_df['Android Ver'].value_counts()
# Out:
# 4.1 and up            2451
# 4.0.3 and up          1501
# 4.0 and up            1375
# Varies with device    1362
# 4.4 and up             980
# 2.3 and up             652
# 5.0 and up             601
# 4.2 and up             394
# 2.3.3 and up           281
# 2.2 and up             244
# 4.3 and up             243
# 3.0 and up             241
# 2.1 and up             134
# 1.6 and up             116
# 6.0 and up              60
# 7.0 and up              42
# 3.2 and up              36
# 2.0 and up              32
# 5.1 and up              24
# 1.5 and up              20
# 4.4W and up             12
# 3.1 and up              10
# 2.0.1 and up             7
# 8.0 and up               6
# 7.1 and up               3
# 4.0.3 - 7.1.1            2
# 5.0 - 8.0                2
# 1.0 and up               2
# 7.0 - 7.1.1              1
# 4.1 - 7.1.1              1
# 5.0 - 6.0                1
# 2.2 - 7.1.1              1
# 5.0 - 7.1.1              1
# Name: Android Ver, dtype: int64

# %% [markdown]
# There are 3 NaN values in the column Android version . since there is no common and it kind of doesnt make any sense if we replace by any value. so it is better to drop the columns

# %%
playstore_df.drop([4453,4490],axis=0,inplace=True)

# %%
playstore_df.shape
# Out:
# (10838, 13)

# %% [markdown]
# 3.Current Ver-- There are a total of 8 NaN/missing values

# %%
playstore_df[playstore_df['Current Ver'].isnull()]
# Out:
#                                    App             Category  Rating Reviews  \
# 15     Learn To Draw Kawaii Characters       ART_AND_DESIGN     3.2      55
# 1553              Market Update Helper   LIBRARIES_AND_DEMO     4.1   20145
# 6322            Virtual DJ Sound Mixer                TOOLS     4.2    4010
# 6803                         BT Master               FAMILY     NaN       0
# 7333                       Dots puzzle               FAMILY     4.0     179
# 7407                   Calculate My IQ               FAMILY     NaN      44
# 7730                            UFO-CQ                TOOLS     NaN       1
# 10342                   La Fe de Jesus  BOOKS_AND_REFERENCE     NaN       8
#
#        Size    Installs  Type  Price Content Rating             Genres  \
# 15     2.7M      5,000+  Free      0       Everyone       Art & Design
# 1553    11k  1,000,000+  Free      0       Everyone   Libraries & Demo
# ...

# %% [markdown]
# Since there are only 8 rows which contain NaN values in the Current Ver column, and there is no  value with which we can replace it,therefore it is better to drop this rows.

# %%
playstore_df=playstore_df[playstore_df["Current Ver"].notna()]

# %%
playstore_df.shape[0]
# Out:
# 10830

# %% [markdown]
# 4.Rating--   1470 NaN values

# %%
playstore_df['Rating'].min(),playstore_df['Rating'].max()
# Out:
# (1.0, 5.0)

# %% [markdown]
# Rating of any app is in between 1 and 5 .The column Rating contains around 13.5% of data and it is not practical to remove it .
#
# Therefore the NaN values can be replaced by median or mean of the rest of rating column

# %%
mean_rating = playstore_df[~playstore_df['Rating'].isnull()]['Rating'].mean()
med_rating = playstore_df[~playstore_df['Rating'].isnull()]['Rating'].median()

# %%
mean_rating, med_rating
# Out:
# (4.191837606837606, 4.3)

# %%
#finding out which one is better using different visualization tools
fig, ax = plt.subplots(2,1, figsize=(12,7))
sns.distplot(playstore_df['Rating'],color='firebrick',ax=ax[0])
sns.boxplot(x='Rating',data=playstore_df, ax=ax[1])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# From the distplot visualizations, it is clear that the ratings are left skewed.
#
# We know that if the variable is skewed, the mean is biased by the values at the far end of the distribution. Therefore, the median is a better representation of the majority of the values in the variable.

# %%
playstore_df['Rating'].fillna(value=med_rating,inplace=True)

# %% [markdown]
# ### 2.dropping Duplicate values

# %%
#dropping the duplicate values in the App column
playstore_df.drop_duplicates(subset = 'App', inplace = True)
playstore_df.shape
# Out:
# (9649, 13)

# %% [markdown]
# ### 3.Removing the special characters

# %% [markdown]
# Removing special characters like  '+', ',' ,'$', 'M', 'k', 'NaN'

# %%
playstore_df['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %%
#Clean special characters  from installs column


playstore_df['Installs'] = playstore_df['Installs'].apply(lambda x: x.replace(',',''))
playstore_df['Installs'] = playstore_df['Installs'].apply(lambda x: x.replace('+',''))
playstore_df['Installs'] = playstore_df['Installs'].astype(dtype = 'int')

# %%
playstore_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size  Installs  Type Price Content Rating  \
# 0     159   19M     10000  Free     0       Everyone
# 1     967   14M    500000  Free     0       Everyone
# 2   87510  8.7M   5000000  Free     0       Everyone
# 3  215644   25M  50000000  Free     0           Teen
# 4     967  2.8M    100000  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
#cleaning special characters from size column 
playstore_df['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '5.5M', '17M', '39M', '31M',
#        '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M', '5.2M',
#        '11M', '24M', 'Varies with device', '9.4M', '15M', '10M', '1.2M',
#        '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k', '3.6M',
#        '5.7M', '8.6M', '2.4M', '27M', '2.7M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
playstore_df['Size'] = playstore_df['Size'].apply(lambda x: x.replace('M', '*1000'))
playstore_df['Size'] = playstore_df['Size'].apply(lambda x: x.replace('k', ''))
playstore_df['Size'].replace('Varies with device', '-1', inplace = True) # changing the text Varies with device to -1 to perform eval operation
playstore_df['Size'] = playstore_df['Size'].apply(lambda x: eval(x))

# %%
playstore_df['Size'] = playstore_df['Size'].replace(-1,np.nan) #Changing the values to null then we can fill them with mean value
playstore_df['Size'].fillna(np.mean(playstore_df['Size']), inplace = True)

# %%
playstore_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews     Size  Installs  Type Price Content Rating  \
# 0     159  19000.0     10000  Free     0       Everyone
# 1     967  14000.0    500000  Free     0       Everyone
# 2   87510   8700.0   5000000  Free     0       Everyone
# 3  215644  25000.0  50000000  Free     0           Teen
# 4     967   2800.0    100000  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
#removing $ sign from Price column
playstore_df[playstore_df['Price']!='0']
# Out:
#                                                  App            Category  \
# 234    TurboScan: scan documents and receipts in PDF            BUSINESS
# 235                   Tiny Scanner Pro: PDF Doc Scan            BUSINESS
# 427                               Puffin Browser Pro       COMMUNICATION
# 476                        Moco+ - Chat, Meet People              DATING
# 477                                       Calculator              DATING
# ...                                              ...                 ...
# 10735                                    FP VoiceBot              FAMILY
# 10760                                Fast Tract Diet  HEALTH_AND_FITNESS
# 10782                        Trine 2: Complete Story                GAME
# 10785                                   sugar, sugar              FAMILY
# 10798                           Word Search Tab 1 FR              FAMILY
#
#        Rating Reviews          Size  Installs  Type   Price Content Rating  \
# ...

# %%
playstore_df['Price'] = playstore_df['Price'].apply(lambda x: x.replace('$', ''))
playstore_df[playstore_df['Price']!='0']
# Out:
#                                                  App            Category  \
# 234    TurboScan: scan documents and receipts in PDF            BUSINESS
# 235                   Tiny Scanner Pro: PDF Doc Scan            BUSINESS
# 427                               Puffin Browser Pro       COMMUNICATION
# 476                        Moco+ - Chat, Meet People              DATING
# 477                                       Calculator              DATING
# ...                                              ...                 ...
# 10735                                    FP VoiceBot              FAMILY
# 10760                                Fast Tract Diet  HEALTH_AND_FITNESS
# 10782                        Trine 2: Complete Story                GAME
# 10785                                   sugar, sugar              FAMILY
# 10798                           Word Search Tab 1 FR              FAMILY
#
#        Rating Reviews          Size  Installs  Type  Price Content Rating  \
# ...

# %%
playstore_df['Price'] = playstore_df['Price'].astype(float)
playstore_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews     Size  Installs  Type  Price Content Rating  \
# 0     159  19000.0     10000  Free    0.0       Everyone
# 1     967  14000.0    500000  Free    0.0       Everyone
# 2   87510   8700.0   5000000  Free    0.0       Everyone
# 3  215644  25000.0  50000000  Free    0.0           Teen
# 4     967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# ### Cleaning User Review Database

# %%
review_df.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
# eliminating the null value from the review database
review_df = review_df[~review_df['Sentiment'].isna()]
review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37432 entries, 0 to 64230
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     37432 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 1.7+ MB

# %% [markdown]
# ## Grouping basis on rating- Adding new column

# %%
def Rat_app(val):
  ''''
  This function help to categories the rating from 1 to 5
  as Top_rated,Above_average,Average & below Average, worst
  '''
  if val>=4:
    return 'Top rated'
  elif val>=3 and val<4:
    return 'Above Average'
  elif val>=2 and val<3:
    return 'Average'
  else:
    return 'Below Average'

# %%
# Applying grouped_rating function
playstore_df['Rating_group']=playstore_df['Rating'].apply(lambda x: Rat_app(x))

# %%
playstore_df['Rating_group'].value_counts()
# Out:
# Top rated        7740
# Above Average    1630
# Average           225
# Below Average      54
# Name: Rating_group, dtype: int64

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1- Major categories of Apps

# %%
# Chart - 1 visualization code
temp = playstore_df['Category'].value_counts().reset_index()
plt.figure(figsize=(12,12))
ax = plt.subplot(111)
plt.pie(x = temp['Category'], labels= temp['index'],autopct= '%1.1f%%')
plt.legend()
ax.legend(bbox_to_anchor=(1.4, 1))
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find out major categories of Apps

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  categories such as Family, Games and tools holds the most number of Apps in the Playstore

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes,It would be helpfull for someone new to app building

# %% [markdown]
# #### Chart - 2- Pair plot- Relationships between the features

# %%
# Converting the datatype of the values in the reviews column from string to int
playstore_df['Reviews'] = playstore_df['Reviews'].astype(int)
playstore_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
# Chart - 2 visualization code

#look for any evident patterns or relationships between the features
Rating = playstore_df['Rating']
Size = playstore_df['Size']
Installs = playstore_df['Installs']
Reviews = playstore_df['Reviews']
Type = playstore_df['Type']
Price = playstore_df['Price']

p = sns.pairplot(pd.DataFrame(list(zip(Rating, Size, np.log(Installs), np.log(Reviews), Price, Type)), 
                        columns=['Rating','Size', 'Installs', 'Reviews', 'Price','Type']), hue='Type')
p.fig.suptitle("Pairwise Plot - Rating, Size, Installs, Reviews, Price",x=0.5, y=1.0, fontsize=16)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Text(0.5, 1.0, 'Pairwise Plot - Rating, Size, Installs, Reviews, Price')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# People always download, install and use the apps based on their necessity or interest. In playstore both free and paid apps are available in all the Genres or Category. Generally people always prefer free apps than paid apps untill all the free apps of the particular Genres or Category is not satisfied or not fullfilled their purpose. So we use pair plot  to understand the best set of features to explain a relationship between two variables or to form the most separated clusters

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.   Most of the apps in playstore are free
# 2.   Free apps have higher size over paid apps
# 3.   As we look into the reviews vs install graph, comparitively people who paid for the app tend to review much than people who use freely
# 4.   As the number of installation increases the number of reviews of the particaular app also increases

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 3 -Correlation Heatmap for Playstore Data

# %%
# Chart - 3 visualization code
# Heat map for play_store
plt.figure(figsize = (20,10))
sns.heatmap(playstore_df.corr(), annot= True)
plt.title('Corelation Heatmap for Playstore Data', size=20)
# Out:
# Text(0.5, 1.0, 'Corelation Heatmap for Playstore Data')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find the correlation between different data in the playstore database

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   There is a strong positive correlation between the Reviews and Installs column.
# *   The Price is slightly negatively correlated with the Rating, Reviews, and Installs. This means that as the prices of the app increases, the average rating, total number of reviews and Installs fall slightly
# *

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights helps in building positive business impact.Infact the rating is slightly positively correlated with installs . That is as the number of installs increases it leads to the increase in rating

# %% [markdown]
# #### Chart - 4 - categories & installs correlation

# %%
# Chart - 4 visualization code
#categories & installs correlation
installs_category=pd.DataFrame(playstore_df, columns=['Category','Installs'])
installs_category=installs_category.groupby('Category')[['Installs']].sum().reset_index()
installs_category
# Out:
#                Category     Installs
# 0        ART_AND_DESIGN    114333100
# 1     AUTO_AND_VEHICLES     53130211
# 2                BEAUTY     27197050
# 3   BOOKS_AND_REFERENCE   1665968576
# 4              BUSINESS    697164865
# 5                COMICS     44981150
# 6         COMMUNICATION  11038276251
# 7                DATING    140926107
# 8             EDUCATION    352952000
# 9         ENTERTAINMENT   2113660000
# 10               EVENTS     15973161
# 11               FAMILY   4427881405
# 12              FINANCE    455348734
# 13       FOOD_AND_DRINK    211798751
# 14                 GAME  13878924415
# 15   HEALTH_AND_FITNESS   1144022512
# 16       HOUSE_AND_HOME     97212461
# 17   LIBRARIES_AND_DEMO     51995910
# 18            LIFESTYLE    503823539
# 19  MAPS_AND_NAVIGATION    503281890
# 20              MEDICAL     38193177
# 21   NEWS_AND_MAGAZINES   2369217760
# 22            PARENTING     31521110
# 23      PERSONALIZATION   1532483782
# ...

# %%
installs_category[['Category','Installs']].set_index('Category').plot(kind='bar')
plt.rcParams['figure.figsize'] = (10, 10)
plt.rc('font', size=10) 
plt.xticks(rotation=90)
plt.title('Category vs Installs')
plt.ylabel('Total Installs in the category')
plt.xlabel('Category')
# Out:
# Text(0.5, 0, 'Category')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To know the Most favourable/Installed category in the Play store

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Highest number of Installs is from the Category Games
# *   Communication comes at second and tools,productivity, social comes respectively after communication

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Even though the number of installs gives a figure, it doesnot mean that they are actually most favourable category.we need to take care of no of apps in that particular category

# %% [markdown]
# #### Chart - 5-Relationship between paid and free apps

# %%
playstore_df.value_counts('Type')
# Out:
# Type
# Free    8896
# Paid     753
# dtype: int64

# %%
#count of paid and free apps

plt.pie(playstore_df.value_counts('Type'), labels={'fre','paid'}, colors={'green','orange'}, autopct='%1.1f%%', shadow=True)

plt.legend()
plt.legend(bbox_to_anchor=(1.4, 1))
plt.title("paid and free apps count")
plt.show()

# %%
# Chart - 5 visualization code
#Category wise free and paid app installs count
cti_df = playstore_df.groupby(['Category','Type'])[['Installs']].sum().unstack().reset_index()
cti_df = cti_df[~cti_df['Installs']['Paid'].isna()].set_index('Category')
cti_df
# Out:
#                          Installs
# Type                         Free        Paid
# Category
# ART_AND_DESIGN       1.143171e+08     16000.0
# AUTO_AND_VEHICLES    5.308006e+07     50150.0
# BOOKS_AND_REFERENCE  1.665945e+09     23316.0
# BUSINESS             6.969521e+08    212775.0
# COMMUNICATION        1.103692e+10   1360050.0
# DATING               1.409148e+08     11350.0
# EDUCATION            3.523500e+08    602000.0
# ENTERTAINMENT        2.113460e+09    200000.0
# EVENTS               1.597316e+07         1.0
# FAMILY               4.407282e+09  20599814.0
# FINANCE              4.551631e+08    185602.0
# FOOD_AND_DRINK       2.117388e+08     60000.0
# GAME                 1.385792e+10  20999965.0
# HEALTH_AND_FITNESS   1.143548e+09    474110.0
# LIBRARIES_AND_DEMO   5.199581e+07       100.0
# LIFESTYLE            5.026444e+08   1179110.0
# MAPS_AND_NAVIGATION  5.031608e+08    121100.0
# MEDICAL              3.763234e+07    560833.0
# ...

# %%
#Plot between Paid and Free installed app counts
ind = cti_df.index
column1 = cti_df['Installs']['Paid']
column2 = cti_df['Installs']['Free']
 

fig, axes = plt.subplots(figsize=(20,10), ncols=2, sharey=True)
fig.tight_layout()

axes[0].barh(ind, column1, align='center', color='green', zorder=10)
axes[0].set_title('Paid app install Counts(in millions)', fontsize=18, pad=15, color='green')
axes[1].barh(ind, column2, align='center', color='red', zorder=10)
axes[1].set_title('Free app install Counts(in 100 millions)', fontsize=18, pad=15, color='red')
# If you have positive numbers and want to invert the x-axis of the left plot
axes[0].invert_xaxis() 

# To show data from highest to lowest
# plt.gca().invert_yaxis()
axes[0].set(yticks=ind, yticklabels=ind)
axes[0].yaxis.tick_left()

plt.subplots_adjust(wspace=0, top=0.85, bottom=0.1, left=0.18, right=0.95)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To know the difference in number of installs between paid and free

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Each category is showing a huge differnece in installs between paid and free apps
# *   people are spending more money on the game and family
# *   communication and games are the most installed free apps categories
# *   the amount of installs in communication category between free and paid is considerably huge

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * people tend to pay more money on categories such as games and family
# *even though communication apps provide lots of paid apps , people tend to use free apps rather than the paid ones

# %% [markdown]
# #### Chart -6- Rating of each category

# %%
# Chart - 6 visualization code
plt.title('Histogram of Rating')
sns.distplot(playstore_df['Rating'], hist=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#mean rating in each category
category_rating_df = playstore_df.groupby(['Category'])['Rating'].mean().reset_index()
category_rating_df.set_index('Category').plot(kind='bar')
plt.rcParams['figure.figsize'] = (10, 10)
plt.rc('font', size=14) 
plt.xticks(rotation=90)
plt.title('Mean Rating of Apps in the category' )
plt.ylabel('Mean ratings of category')
plt.xlabel('Category')
# Out:
# Text(0.5, 0, 'Category')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find out the category which has got lesser rating and higher rating

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *  Almost every categories Rating is somewhat same
# *  Every category has a mean rating of more than 4

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 7 - Content rating vs Number of installs

# %%
# Chart - 7 visualization code
playstore_df['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated'], dtype=object)

# %%
Content_installs=playstore_df.groupby(['Content Rating'])['Installs'].sum()
Content_installs
# Out:
# Content Rating
# Adults only 18+        2000000
# Everyone           52177775851
# Everyone 10+        4016271795
# Mature 17+          2437986878
# Teen               16487275393
# Unrated                  50500
# Name: Installs, dtype: int64

# %%
Content_installs.plot(kind='pie',explode= (0.1,0.02,0.03,0.04,0.05,0.01),pctdistance=1.1,labeldistance=1.2,autopct='%1.2f%%',shadow=True)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To know the Installed count on variety of content rating

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Mostly people download/install apps that can use by everyone
# *   second most downlaoded apps that can be used by atleast become teens
# * 18+ apps are downloaded by a minute amount of people compared to others

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8 -relationship between sentiment_polarity and sentiment _objectivity

# %%
# Chart - 8 visualization code
#Relationship between Sentiment_Polarity and 	Sentiment_Subjectivity
sns.scatterplot(review_df['Sentiment_Subjectivity'], review_df['Sentiment_Polarity'])
plt.title("Relationship between sentiment_subjectivity and sentiment_polarity")
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Relationship between sentiment_subjectivity and sentiment_polarity')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find the Relationship between sentiment_subjectivity and sentiment_polarity

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The maximum number of sentiment subjectivity lies between 0.4 to 0.7
# *  sentiment subjectivity is not always proportional to sentiment polarity

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Sentiment subjectivity gives how close a reviewers opinion is to the opinion of the general public.Higher the subjectivity, closer is the reviewers opinion to the opinion of the general public. As the maximum number of sentiment subjectivity lies between 0.4 to 0.8 , we could believe the reviewers opinion

# %% [markdown]
# #### Chart - 9- sentiment analysis

# %%
# Chart - 9 visualization code
import matplotlib
counts = list(review_df['Sentiment'].value_counts())
labels = 'Positive Reviews', 'Negative Reviews','Neutral Reviews'
matplotlib.rcParams['font.size'] = 20
matplotlib.rcParams['figure.figsize'] = (10, 15)
plt.pie(counts, labels=labels, explode=[0.01, 0.05, 0.05], shadow=True, autopct="%.2f%%")
plt.title('Percentage of Review Sentiments', fontsize=20)
plt.axis('off')
plt.legend(bbox_to_anchor=(0.9, 0, 0.5, 1))
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To understand the likeness of reviewers over the apps in the playstore

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Positive reviews are 64.30%
# * Negative reviews are 22.80%
# * Neutral reviews are 12.90%

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We could understand the behaviour of the users in the playstore . As we can see about 64% of people posting positive reviews and its a good thing

# %% [markdown]
# #### Chart - 10 - Apps with highest number of positive reviews

# %%
# Chart - 10 visualization code
positive_df=review_df[review_df['Sentiment']=='Positive']
positive_df
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# 5               10 Best Foods for You
# ...                               ...
# 64217  Housing-Real Estate & Property
# 64221  Housing-Real Estate & Property
# 64222  Housing-Real Estate & Property
# 64223  Housing-Real Estate & Property
# 64227  Housing-Real Estate & Property
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# 5                                               Best way  Positive
# ...                                                  ...       ...
# ...

# %%
positive_df.groupby('App')['Sentiment'].value_counts().nlargest(10).plot.barh(figsize=(10,8),color='red').invert_yaxis()
plt.title("Top 10 positive review apps")
plt.xlabel('Total number of positive reviews')
plt.legend()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# TO find the top positive reviewed apps

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Helix jump has the highest number of positive ratings

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ### Chart - 11 - Apps recieved most negative reviews

# %%
#chart-11 visualization code
negative_df=review_df[review_df['Sentiment']=='Negative']
negative_df
# Out:
#                                   App  \
# 32              10 Best Foods for You
# 43              10 Best Foods for You
# 68              10 Best Foods for You
# 85              10 Best Foods for You
# 95              10 Best Foods for You
# ...                               ...
# 64215  Housing-Real Estate & Property
# 64216  Housing-Real Estate & Property
# 64220  Housing-Real Estate & Property
# 64226  Housing-Real Estate & Property
# 64230  Housing-Real Estate & Property
#
#                                        Translated_Review Sentiment  \
# 32                    No recipe book Unable recipe book.  Negative
# 43     Waste time It needs internet time n ask calls ...  Negative
# 68                               Faltu plz waste ur time  Negative
# 85                                     Crap Doesn't work  Negative
# 95     Boring. I thought actually just texts that's i...  Negative
# ...                                                  ...       ...
# ...

# %%
negative_df.groupby('App')['Sentiment'].value_counts().nlargest(10).plot.barh(figsize=(10,8),color='red').invert_yaxis()
plt.title("Top 10 negative review apps")
plt.xlabel('Total number of negative reviews')
plt.legend()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find the  top negative reviewed apps

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *  Angry birds classic is the most negative reviewed app

# %% [markdown]
# #### Chart - 12 - reviews across categories

# %%
play_rev_df = playstore_df.merge(review_df, on="App")
play_rev_df.head(3)
# Out:
#                    App        Category  Rating  Reviews     Size  Installs  \
# 0  Coloring book moana  ART_AND_DESIGN     3.9      967  14000.0    500000
# 1  Coloring book moana  ART_AND_DESIGN     3.9      967  14000.0    500000
# 2  Coloring book moana  ART_AND_DESIGN     3.9      967  14000.0    500000
#
#    Type  Price Content Rating                     Genres      Last Updated  \
# 0  Free    0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 1  Free    0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 2  Free    0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
#
#   Current Ver   Android Ver   Rating_group  \
# 0       2.0.0  4.0.3 and up  Above Average
# 1       2.0.0  4.0.3 and up  Above Average
# 2       2.0.0  4.0.3 and up  Above Average
#
#                                    Translated_Review Sentiment  \
# 0  A kid's excessive ads. The types ads allowed a...  Negative
# ...

# %%
catewise_review_count = play_rev_df.groupby(['Category']).size().reset_index(name='Total Sentiment Count')
catewise_review_count.sort_values('Total Sentiment Count' , ascending  = False).head(2)
# Out:
#               Category  Total Sentiment Count
# 14                GAME                   6678
# 15  HEALTH_AND_FITNESS                   2250

# %%
catewise_review_count.set_index('Category').plot(kind='bar')
plt.rcParams['figure.figsize'] = (10, 10)
plt.rc('font', size=14) 
plt.xticks(rotation=90)
plt.title('Categroy vs sentimental count' )
plt.ylabel('total sentimental count')
plt.xlabel('Category')
# Out:
# Text(0.5, 0, 'Category')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find the category having the highest and lowest sentimental count

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *  games have highest sentimentality
# * comics have the lowest sentimentality acccording to category

# %% [markdown]
# #### Chart - 13 - App pricing across categories

# %%
#App pricing across categories 
categrory_price_df = playstore_df[playstore_df['Price'] !=  0].groupby(['Category'])['Price'].mean().reset_index(name='Price')
ax = sns.stripplot(x='Price', y='Category', data=categrory_price_df, jitter=True, linewidth=1)
ax.set_title('App pricing trend across categories(in USD)')
# Out:
# Text(0.5, 1.0, 'App pricing trend across categories(in USD)')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To show the price range across different categories

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * most of the categories have a price range in between 0 and 25
# * categories like events , finance, lifestyle have a price varied vastly from other categories

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Play store has enormous potential to drive app making business to success.it is important to know the charactersticts of play store to have a better understanding to invest in. Various factors like categories,no of installs, app rating, app cost,size,type of people that can use the app need to be studied to have a better understanding of the working of playstore \
#
# Eventhough Most apps belong to the category family games and tools , most installed belongs to  games, communication and tools. so  there is  vast number of family apps but installed figures doesnot sum up to the total apps count. so its good not to invest in family apps \
#
# Its always important to know the demand of paid and free apps
# paid apps contain almost 92 % of free apps and rest is paid. Apps in game category provides a proportional amount of installs as per paid and free apps . Games and family are the two topmost installed paid apps. So if you are interested in building apps that involves money, then categories like games and family is more preferable \
#
# Various constraints like review ,category, size, installed count etc need to count on to obtain the clients business objective \
#
# Reviews affects the app, eventhough at an average every category of apps has got a rating of above 4.most liked app is helix jump

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# * categories such as Family, Games and tools holds the most number of Apps in the Playstore
# * Most of the apps in playstore are free
# Free apps have higher size over paid apps
# * The Price is slightly negatively correlated with the Rating, Reviews, and Installs. This means that as the prices of the app increases, the average rating, total number of reviews and Installs fall slightly
# * Highest number of Installs is from the Category Games.Communication comes at second and tools,productivity, social comes respectively after communication
# * Each category is showing a huge differnece in installs between paid and free apps.
# people are spending more money on the game and family.
# communication and games are the most installed free apps categories.
# the amount of installs in communication category between free and paid is considerably huge.
# * Most of the rating is in between 4.0 to 4.5
# * games have highest sentimentality,comics have the lowest sentimentality acccording to category
# * Mostly people download/install apps that can use by everyone.
# second most downlaoded apps that can be used by atleast become teens.
# 18+ apps are downloaded by a minute amount of people compared to others.
# * The maximum number of sentiment subjectivity lies between 0.4 to 0.7, and
# sentiment subjectivity is not always proportional to sentiment polarity.From this we can conclude that maximum number of users give reviews to the applications, according to their experience
# * Positive reviews are 64.30%
# ,Negative reviews are 22.80%
# and Neutral reviews are 12.90% hence a large number of people using playstore were satisfied
# *most of the categories have a price range in between 0 and 25.
# categories like events , finance, lifestyle have a price varied vastly from other categories

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
